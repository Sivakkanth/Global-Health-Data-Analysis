# %% [markdown]
# <a href="https://colab.research.google.com/github/Sivakkanth/EnvironementSensorDataAnalysis/blob/main/Cloud_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("garystafford/environmental-sensor-data-132k")
print("path of the downloaded file" + path)
# Out:
# path of the downloaded file/kaggle/input/environmental-sensor-data-132k

# %%
import os
print(os.listdir(path))
# Out:
# ['iot_telemetry_data.csv']

# %%
import pandas as pd
csv_file = os.path.join(path, "iot_telemetry_data.csv")
df = pd.read_csv(csv_file);
df
# Out:
#                   ts             device        co   humidity  light       lpg  \
# 0       1.594512e+09  b8:27:eb:bf:9d:51  0.004956  51.000000  False  0.007651
# 1       1.594512e+09  00:0f:00:70:91:0a  0.002840  76.000000  False  0.005114
# 2       1.594512e+09  b8:27:eb:bf:9d:51  0.004976  50.900000  False  0.007673
# 3       1.594512e+09  1c:bf:ce:15:ec:4d  0.004403  76.800003   True  0.007023
# 4       1.594512e+09  b8:27:eb:bf:9d:51  0.004967  50.900000  False  0.007664
# ...              ...                ...       ...        ...    ...       ...
# 405179  1.595203e+09  00:0f:00:70:91:0a  0.003745  75.300003  False  0.006247
# 405180  1.595203e+09  b8:27:eb:bf:9d:51  0.005882  48.500000  False  0.008660
# 405181  1.595203e+09  1c:bf:ce:15:ec:4d  0.004540  75.699997   True  0.007181
# 405182  1.595203e+09  00:0f:00:70:91:0a  0.003745  75.300003  False  0.006247
# 405183  1.595203e+09  b8:27:eb:bf:9d:51  0.005914  48.400000  False  0.008695
#
# ...

# %%
df.dtypes
# Out:
# ts          float64
# device       object
# co          float64
# humidity    float64
# light          bool
# lpg         float64
# motion         bool
# smoke       float64
# temp        float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405184 entries, 0 to 405183
# Data columns (total 9 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   ts        405184 non-null  float64
#  1   device    405184 non-null  object
#  2   co        405184 non-null  float64
#  3   humidity  405184 non-null  float64
#  4   light     405184 non-null  bool
#  5   lpg       405184 non-null  float64
#  6   motion    405184 non-null  bool
#  7   smoke     405184 non-null  float64
#  8   temp      405184 non-null  float64
# dtypes: bool(2), float64(6), object(1)
# memory usage: 22.4+ MB

# %%
df.tail()
# Out:
#                   ts             device        co   humidity  light       lpg  \
# 405179  1.595203e+09  00:0f:00:70:91:0a  0.003745  75.300003  False  0.006247
# 405180  1.595203e+09  b8:27:eb:bf:9d:51  0.005882  48.500000  False  0.008660
# 405181  1.595203e+09  1c:bf:ce:15:ec:4d  0.004540  75.699997   True  0.007181
# 405182  1.595203e+09  00:0f:00:70:91:0a  0.003745  75.300003  False  0.006247
# 405183  1.595203e+09  b8:27:eb:bf:9d:51  0.005914  48.400000  False  0.008695
#
#         motion     smoke       temp
# 405179   False  0.016437  19.200001
# 405180   False  0.023301  22.200000
# 405181   False  0.019076  26.600000
# 405182   False  0.016437  19.200001
# 405183   False  0.023400  22.200000

# %%
df.head()
# Out:
#              ts             device        co   humidity  light       lpg  \
# 0  1.594512e+09  b8:27:eb:bf:9d:51  0.004956  51.000000  False  0.007651
# 1  1.594512e+09  00:0f:00:70:91:0a  0.002840  76.000000  False  0.005114
# 2  1.594512e+09  b8:27:eb:bf:9d:51  0.004976  50.900000  False  0.007673
# 3  1.594512e+09  1c:bf:ce:15:ec:4d  0.004403  76.800003   True  0.007023
# 4  1.594512e+09  b8:27:eb:bf:9d:51  0.004967  50.900000  False  0.007664
#
#    motion     smoke       temp
# 0   False  0.020411  22.700000
# 1   False  0.013275  19.700001
# 2   False  0.020475  22.600000
# 3   False  0.018628  27.000000
# 4   False  0.020448  22.600000

# %%
# Step 5: Check for missing values
print("\n🧹 Missing Values Count:")
print(df.isnull().sum())
# Out:
# 🧹 Missing Values Count:
# ts          0
# device      0
# co          0
# humidity    0
# light       0
# lpg         0
# motion      0
# smoke       0
# temp        0
# dtype: int64

# %%
# Step 6: Check row count (should be >= 100,000 for this assignment)
print(f"\n📏 Total Rows: {len(df)}")
if len(df) >= 100000:
    print("✅ Sufficient data size.")
else:
    print("⚠️ Dataset might be too small for large-scale MapReduce.")
# Out:
# 📏 Total Rows: 405184
# ✅ Sufficient data size.

# %%
# Download the updated table as CSV on colab
res.to_csv('EnvironmentSensor.csv')

# %%
# Download the csv file to local machine
from google.colab import files
files.download('EnvironmentSensor.csv')

# %%
df.columns()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ea942bf769f0> in <cell line: 0>()
# ----> 1 df.columns()
#
# NameError: name 'df' is not defined
